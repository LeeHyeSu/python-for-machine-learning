# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(size):
    x = np.linspace(0, 5, size)
    y = x * np.sin(x ** 2) + 1
    return (x,y)

def sample(size):
    x = np.linspace(0, 5, size)
    y = x * np.sin(x ** 2) + 1 + np.random.randn(x.size)*0.5
    return (x,y)

# %%
f_x, f_y = f(1000)
plt.plot(f_x, f_y)
X, y = sample(1000)
plt.scatter(X, y, s=3, c="black")
plt.show()

# %%
X.shape, y.shape
# Out:
# ((1000,), (1000,))

# %%
X = X.reshape(-1,1)
y = y.reshape(-1,1)
X.shape, y.shape
# Out:
# ((1000, 1), (1000, 1))

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
f_x, f_y = f(1000)
plt.plot(f_x, f_y)
plt.scatter(X.flatten(), y.flatten(), s=3, c="black")
plt.plot(X.flatten(), lr.predict(X).flatten())
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_features = PolynomialFeatures(degree=2)
X_poly = poly_features.fit_transform(X)
X_poly[:10]
# Out:
# array([[1.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 5.00500501e-03, 2.50500751e-05],
#        [1.00000000e+00, 1.00100100e-02, 1.00200300e-04],
#        [1.00000000e+00, 1.50150150e-02, 2.25450676e-04],
#        [1.00000000e+00, 2.00200200e-02, 4.00801202e-04],
#        [1.00000000e+00, 2.50250250e-02, 6.26251878e-04],
#        [1.00000000e+00, 3.00300300e-02, 9.01802704e-04],
#        [1.00000000e+00, 3.50350350e-02, 1.22745368e-03],
#        [1.00000000e+00, 4.00400400e-02, 1.60320481e-03],
#        [1.00000000e+00, 4.50450450e-02, 2.02905608e-03]])

# %%
lr = LinearRegression()
lr.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
f_x, f_y = f(1000)
plt.plot(f_x, f_y)
plt.scatter(X.flatten(), y.flatten(), s=3, c="black")
plt.plot(X.flatten(), lr.predict(X_poly).flatten())
plt.show()

# %%
poly_features = PolynomialFeatures(degree=16)
X_poly = poly_features.fit_transform(X)
X_poly[:3]
# Out:
# array([[1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [1.00000000e+00, 5.00500501e-03, 2.50500751e-05, 1.25375751e-07,
#         6.27506263e-10, 3.14067198e-12, 1.57190790e-14, 7.86740691e-17,
#         3.93764110e-19, 1.97079134e-21, 9.86382051e-24, 4.93684710e-26,
#         2.47089445e-28, 1.23668391e-30, 6.18960915e-33, 3.09790248e-35,
#         1.55050174e-37],
#        [1.00000000e+00, 1.00100100e-02, 1.00200300e-04, 1.00300601e-06,
#         1.00401002e-08, 1.00501504e-10, 1.00602106e-12, 1.00702808e-14,
#         1.00803612e-16, 1.00904517e-18, 1.01005522e-20, 1.01106629e-22,
#         1.01207837e-24, 1.01309146e-26, 1.01410556e-28, 1.01512068e-30,
#         1.01613682e-32]])

# %%
lr = LinearRegression()
lr.fit(X_poly,y)
f_x, f_y = f(1000)
plt.plot(f_x, f_y)
plt.scatter(X.flatten(), y.flatten(), s=3, c="black")
plt.plot(X.flatten(), lr.predict(X_poly).flatten())
plt.show()

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

# %%
poly_range = list(range(10, 50))
rmse_lr_list = []
rmse_lasso_list = []
rmse_ridge_list = []

from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

for poly_value in poly_range:
    poly_features = PolynomialFeatures(degree=poly_value)
    X_poly = poly_features.fit_transform(X)
    lr = LinearRegression()
    lr.fit(X_poly,y)
    
    rmse_lr_list.append(rmse(lr.predict(X_poly), y))

    lasso = Lasso()
    lasso.fit(X_poly,y)
    rmse_lasso_list.append(rmse(lasso.predict(X_poly), y))
    
    ridge = Ridge()
    ridge.fit(X_poly,y)
    rmse_ridge_list.append(rmse(ridge.predict(X_poly), y))
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2001.6107639519662, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1995.6624825603133, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=9.00523e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1990.0400008977472, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=3.85959e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1984.6547849696776, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.64691e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1979.8375140303838, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=6.99999e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1976.0692333905272, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1973.4466200589716, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1971.8800724035227, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1971.1649862960544, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1971.0475179834011, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1971.2655123561783, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1971.5853401175773, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1971.788049609372, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1971.7198978338238, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1971.2502421009758, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1970.2569287340518, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1968.6550675981623, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1966.3595319217843, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1963.2929909437028, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1959.3876405654828, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1954.601098790045, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1948.9060192160828, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1942.3060346377933, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1934.8308614005225, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1926.543050864725, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1917.9552592006125, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1911.300369735116, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1904.3583609065747, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1897.3327645429633, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1890.131256118545, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1882.780337179566, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1875.342782563667, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1867.8792739027638, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1860.4610129526054, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1853.1466336328301, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1846.0167648778067, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1839.1122271696356, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1832.4875566813646, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1826.1755728009225, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1820.2115904006332, tolerance: 0.43940768383961804
#   model = cd_fast.enet_coordinate_descent(

# %%
import pandas as pd
from pandas import DataFrame
data = {"poly_range":poly_range, "lr_rmse":rmse_lr_list, 
        "lasso_rmse":rmse_lasso_list,"ridge_rmse":rmse_ridge_list}
df = DataFrame(data).set_index("poly_range")
df
# Out:
#              lr_rmse  lasso_rmse  ridge_rmse
# poly_range
# 10          1.876816    2.185843    1.905397
# 11          1.868193    2.193748    1.883395
# 12          1.607622    2.198408    1.882225
# 13          1.342922    2.200923    1.856372
# 14          1.331485    2.202318    1.680433
# 15          0.931832    2.203020    1.465448
# 16          0.731542    2.203248    1.474093
# 17          0.696869    2.203139    1.284405
# 18          0.723624    2.202802    0.890162
# 19          0.682245    2.202348    0.770607
# 20          0.674523    2.201895    0.763056
# 21          0.645247    2.201568    0.629948
# 22          0.553392    2.201488    0.527581
# 23          0.533434    2.201770    0.521415
# 24          0.598899    2.202507    0.538569
# 25          0.684601    2.203761    0.661506
# 26          0.784460    2.205565    0.653959
# 27          0.954275    2.207916    0.665413
# 28          1.086804    2.210784    0.970360
# 29          1.153273    2.214112    0.998433
# 30          1.152883    2.217833    1.054716
# 31          1.242852    2.221872    1.076706
# 32          1.296603    2.226153    1.665710
# 33          1.330245    2.230602    1.164063
# 34          1.338395    2.235155    1.078109
# 35          1.324596    2.240060    3.073853
# 36          1.297576    2.246567    2.855942
# 37          1.268250    2.252622    1.236858
# 38          1.247592    2.258196    1.414830
# 39          1.240199    2.263399    1.289055
# 40          1.250148    2.268239    1.328778
# 41          1.285101    2.272735    1.272248
# 42          1.510126    2.276903    1.392563
# 43          1.499253    2.280763    1.341356
# 44          1.556518    2.284328    1.470821
# 45          1.471672    2.287614    1.457328
# 46          1.485434    2.290633    1.473643
# 47          1.493165    2.293393    1.497770
# 48          1.528698    2.295904    1.619259
# 49          1.454584    2.298175    1.513409

# %%
plt.plot(poly_range, df["ridge_rmse"], label="ridge")
plt.plot(poly_range, df["lr_rmse"], label="lr")
plt.plot(poly_range, df["lasso_rmse"], label="lasso")
plt.legend()
plt.show()

# %%
df.min()
# Out:
# lr_rmse       0.533434
# lasso_rmse    2.185843
# ridge_rmse    0.521415
# dtype: float64

# %%
df["ridge_rmse"].sort_values().head()
# Out:
# poly_range
# 23    0.521415
# 22    0.527581
# 24    0.538569
# 21    0.629948
# 26    0.653959
# Name: ridge_rmse, dtype: float64

# %%
poly_features = PolynomialFeatures(degree=22)
X_poly = poly_features.fit_transform(X)
ridge = Ridge(fit_intercept=False)
ridge.fit(X_poly,y)
# Out:
# Ridge(fit_intercept=False)

# %%
f_x, f_y = f(1000)
plt.plot(f_x, f_y)
plt.scatter(X.flatten(), y.flatten(), s=3, c="black")
plt.plot(X.flatten(), ridge.predict(X_poly).flatten())
plt.show()

# %% [markdown]
# # Exercises problem
#
# data from - https://onlinecourses.science.psu.edu/stat501/node/325

# %%
df = pd.read_csv("./data/yield.csv",sep="\t")
df.head()
# Out:
#    i  Temp  Yield
# 0  1    50    3.3
# 1  2    50    2.8
# 2  3    50    2.9
# 3  4    70    2.3
# 4  5    70    2.6

# %%
plt.scatter(df["Temp"], df["Yield"])
plt.show()
